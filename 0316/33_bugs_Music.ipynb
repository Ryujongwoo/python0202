# %%
# 벅스 뮤직 Top 100 크롤링
import requests
from bs4 import BeautifulSoup
targetSite = 'https://music.bugs.co.kr/chart'

# %%
request = requests.get(targetSite)
# print(request)
html = request.text
# print(html)
soup = BeautifulSoup(html, 'html.parser')
# print(soup)

# %%
# 노래 제목 크롤링
titles = soup.findAll('p', {'class': 'title'})
# print(titles)
print(len(titles))
for title in titles:
    print(title.text.strip())
# Out:
# 100
# WANNABE
# 시작
# 문득
# 돌덩이
# 어떻게 지내
# FIESTA
# 아무노래
# 흔들리는 꽃들 속에서 네 샴푸향이 느껴진거야
# 하루종일
# 그때 그 아인
# 마음을 드려요
# 찐이야
# ON
# METEOR
# To Die For
# Blueming
# Psycho
# Birthday
# 바빠서 (Feat. 헤이즈)
# HIP
# Sweet Night
# 영웅 (英雄; Kick It)
# 사랑의 인사
# Maniac
# 이 또한 지나가리라
# Square (2017)
# 솔직히 지친다
# 막걸리 한잔
# 반만
# 늦은 밤 너의 집 앞 골목길에서
# Don't Start Now
# 다시 난, 여기
# 2002
# Memories
# 18세 순이
# 어느 60대 노부부이야기
# 둘만의 세상으로 가
# Changes
# 어떻게 이별까지 사랑하겠어, 널 사랑하는 거지
# Painkiller
# 배신자
# 추억으로 가는 당신
# Love poem
# 사계 (Four Seasons)
# 오늘도 빛나는 너에게 (To You My Light) (Feat.이라온)
# 모든 날, 모든 순간 (Every day, Every Moment)
# Nerdy Love (Feat. 백예린)
# 보라빛 엽서
# 진또배기
# 너에게 가는 이 길 위에서 (너.이.길)
# 여백
# 파트너
# 친구
# ROXANNE
# 00:00 (Zero O’Clock)
# Say
# bad guy
# 너를 사랑하고 있어
# 작은 것들을 위한 시 (Boy With Luv) (Feat. Halsey)
# 시든 꽃에 물을 주듯
# 고맙소
# 안녕
# 바램
# 또 사랑에 속다
# 신혼일기
# 마음이 말하는 행복 (Happiness) (Feat.이라온)
# 기댈 곳
# 주저하는 연인들을 위해
# Know Me Too Well
# Paris In The Rain
# Who (feat. BTS)
# 너의 하루는 좀 어때
# 나의 오랜 연인에게
# 밤편지
# Into the Unknown
# Feel Special
# 누가 울어
# 다시 만날까 봐
# 너를 만나
# 미친 사랑의 노래
# 빌었어
# Señorita
# Flower
# Black Swan
# 시간의 바깥
# 여인의 향기
# Filter
# 딱! 풀
# 불티 (Spark)
# 어떤 날엔
# 내게 들려주고 싶은 말 (Dear Me)
# comethru
# 나의 모든 날
# LION
# 일편단심 민들레야
# 두 주먹
# 그대라는 시
# 울긴 왜 울어
# 울면서 후회하네
# 내 삶의 이유 있음은

# %%
# 가수 이름 크롤링
artists = soup.findAll('p', {'class': 'artist'})
# print(artists)
print(len(artists))
for artist in artists:
    print(artist.text.strip().split('\n')[0])
# Out:
# 100
# ITZY (있지)
# 가호(Gaho)
# 노을
# 하현우(국카스텐)
# 오반
# IZ*ONE(아이즈원)
# 지코 (ZICO)
# 장범준
# 규현 (KYUHYUN)
# 김필(Kim Feel)
# 아이유(IU)
# 영탁
# 방탄소년단
# 창모(CHANGMO)
# Sam Smith(샘 스미스)
# 아이유(IU)
# Red Velvet (레드벨벳)
# Anne-Marie(앤 마리)
# 개코
# 마마무(Mamamoo)
# V
# NCT 127
# 씨야(SeeYa)
# Conan Gray
# 신승훈
# 백예린
# 청하
# 영탁
# 진민호
# 노을
# Dua Lipa(두아 리파)
# 백예린
# Anne-Marie(앤 마리)
# Maroon 5(마룬 파이브)
# 이찬원
# 임영웅
# Crush
# Lauv(라우브)
# AKMU (악동뮤지션)
# Ruel(루엘)
# 임영웅
# 영탁
# 아이유(IU)
# 태연 (TAEYEON)
# 마크툽(Maktub)
# 폴킴(Paul Kim)
# pH-1
# 임영웅
# 이찬원
# 백현(BAEKHYUN)
# 정동원
# 정동원
# 방탄소년단
# Arizona Zervas
# 방탄소년단
# 윤미래
# Billie Eilish(빌리 아일리시)
# 백현(BAEKHYUN)
# 방탄소년단
# HYNN(박혜원)
# 김호중
# 폴킴(Paul Kim)
# 임영웅
# 에이트(8Eight)
# 윤딴딴
# 마크툽(Maktub)
# 윤딴딴
# 잔나비
# New Hope Club(뉴 호프 클럽)
# Lauv(라우브)
# Lauv(라우브)
# 거미
# 다비치
# 아이유(IU)
# Idina Menzel(이디나 멘젤)
# TWICE (트와이스)
# 정동원
# V.O.S.
# 폴킴(Paul Kim)
# 씨야(SeeYa)
# 창모(CHANGMO)
# Shawn Mendes(션 멘데스)
# 윤미래
# 방탄소년단
# 아이유(IU)
# 씨야(SeeYa)
# 방탄소년단
# 이찬원
# 태연 (TAEYEON)
# 김재환
# 태연 (TAEYEON)
# Jeremy Zucker
# 세정
# (여자)아이들
# 임영웅
# 임영웅
# 태연 (TAEYEON)
# 이찬원
# 임영웅
# 영탁

# %%
bugs = [] # 노래 제목과 가수를 하나의 리스트로 만들어 저장할 빈 리스트를 선언한다.
titles = soup.findAll('p', {'class': 'title'})
artists = soup.findAll('p', {'class': 'artist'})
for i in range(len(titles)):
    bugs.append([titles[i].text.strip(), artists[i].text.strip().split('\n')[0]])
# print(bugs)

from datetime import datetime as dt
print(dt.now(), '현재')
for i in range(len(bugs)):
    print('{0:3d}위. {1} - {2}'.format(i + 1, bugs[i][0], bugs[i][1]))
# Out:
# 2020-03-16 22:17:36.365644 현재
#   1위. WANNABE - ITZY (있지)
#   2위. 시작 - 가호(Gaho)
#   3위. 문득 - 노을
#   4위. 돌덩이 - 하현우(국카스텐)
#   5위. 어떻게 지내 - 오반
#   6위. FIESTA - IZ*ONE(아이즈원)
#   7위. 아무노래 - 지코 (ZICO)
#   8위. 흔들리는 꽃들 속에서 네 샴푸향이 느껴진거야 - 장범준
#   9위. 하루종일 - 규현 (KYUHYUN)
#  10위. 그때 그 아인 - 김필(Kim Feel)
#  11위. 마음을 드려요 - 아이유(IU)
#  12위. 찐이야 - 영탁
#  13위. ON - 방탄소년단
#  14위. METEOR - 창모(CHANGMO)
#  15위. To Die For - Sam Smith(샘 스미스)
#  16위. Blueming - 아이유(IU)
#  17위. Psycho - Red Velvet (레드벨벳)
#  18위. Birthday - Anne-Marie(앤 마리)
#  19위. 바빠서 (Feat. 헤이즈) - 개코
#  20위. HIP - 마마무(Mamamoo)
#  21위. Sweet Night - V
#  22위. 영웅 (英雄; Kick It) - NCT 127
#  23위. 사랑의 인사 - 씨야(SeeYa)
#  24위. Maniac - Conan Gray
#  25위. 이 또한 지나가리라 - 신승훈
#  26위. Square (2017) - 백예린
#  27위. 솔직히 지친다 - 청하
#  28위. 막걸리 한잔 - 영탁
#  29위. 반만 - 진민호
#  30위. 늦은 밤 너의 집 앞 골목길에서 - 노을
#  31위. Don't Start Now - Dua Lipa(두아 리파)
#  32위. 다시 난, 여기 - 백예린
#  33위. 2002 - Anne-Marie(앤 마리)
#  34위. Memories - Maroon 5(마룬 파이브)
#  35위. 18세 순이 - 이찬원
#  36위. 어느 60대 노부부이야기 - 임영웅
#  37위. 둘만의 세상으로 가 - Crush
#  38위. Changes - Lauv(라우브)
#  39위. 어떻게 이별까지 사랑하겠어, 널 사랑하는 거지 - AKMU (악동뮤지션)
#  40위. Painkiller - Ruel(루엘)
#  41위. 배신자 - 임영웅
#  42위. 추억으로 가는 당신 - 영탁
#  43위. Love poem - 아이유(IU)
#  44위. 사계 (Four Seasons) - 태연 (TAEYEON)
#  45위. 오늘도 빛나는 너에게 (To You My Light) (Feat.이라온) - 마크툽(Maktub)
#  46위. 모든 날, 모든 순간 (Every day, Every Moment) - 폴킴(Paul Kim)
#  47위. Nerdy Love (Feat. 백예린) - pH-1
#  48위. 보라빛 엽서 - 임영웅
#  49위. 진또배기 - 이찬원
#  50위. 너에게 가는 이 길 위에서 (너.이.길) - 백현(BAEKHYUN)
#  51위. 여백 - 정동원
#  52위. 파트너 - 정동원
#  53위. 친구 - 방탄소년단
#  54위. ROXANNE - Arizona Zervas
#  55위. 00:00 (Zero O’Clock) - 방탄소년단
#  56위. Say - 윤미래
#  57위. bad guy - Billie Eilish(빌리 아일리시)
#  58위. 너를 사랑하고 있어 - 백현(BAEKHYUN)
#  59위. 작은 것들을 위한 시 (Boy With Luv) (Feat. Halsey) - 방탄소년단
#  60위. 시든 꽃에 물을 주듯 - HYNN(박혜원)
#  61위. 고맙소 - 김호중
#  62위. 안녕 - 폴킴(Paul Kim)
#  63위. 바램 - 임영웅
#  64위. 또 사랑에 속다 - 에이트(8Eight)
#  65위. 신혼일기 - 윤딴딴
#  66위. 마음이 말하는 행복 (Happiness) (Feat.이라온) - 마크툽(Maktub)
#  67위. 기댈 곳 - 윤딴딴
#  68위. 주저하는 연인들을 위해 - 잔나비
#  69위. Know Me Too Well - New Hope Club(뉴 호프 클럽)
#  70위. Paris In The Rain - Lauv(라우브)
#  71위. Who (feat. BTS) - Lauv(라우브)
#  72위. 너의 하루는 좀 어때 - 거미
#  73위. 나의 오랜 연인에게 - 다비치
#  74위. 밤편지 - 아이유(IU)
#  75위. Into the Unknown - Idina Menzel(이디나 멘젤)
#  76위. Feel Special - TWICE (트와이스)
#  77위. 누가 울어 - 정동원
#  78위. 다시 만날까 봐 - V.O.S.
#  79위. 너를 만나 - 폴킴(Paul Kim)
#  80위. 미친 사랑의 노래 - 씨야(SeeYa)
#  81위. 빌었어 - 창모(CHANGMO)
#  82위. Señorita - Shawn Mendes(션 멘데스)
#  83위. Flower - 윤미래
#  84위. Black Swan - 방탄소년단
#  85위. 시간의 바깥 - 아이유(IU)
#  86위. 여인의 향기 - 씨야(SeeYa)
#  87위. Filter - 방탄소년단
#  88위. 딱! 풀 - 이찬원
#  89위. 불티 (Spark) - 태연 (TAEYEON)
#  90위. 어떤 날엔 - 김재환
#  91위. 내게 들려주고 싶은 말 (Dear Me) - 태연 (TAEYEON)
#  92위. comethru - Jeremy Zucker
#  93위. 나의 모든 날 - 세정
#  94위. LION - (여자)아이들
#  95위. 일편단심 민들레야 - 임영웅
#  96위. 두 주먹 - 임영웅
#  97위. 그대라는 시 - 태연 (TAEYEON)
#  98위. 울긴 왜 울어 - 이찬원
#  99위. 울면서 후회하네 - 임영웅
# 100위. 내 삶의 이유 있음은 - 영탁
