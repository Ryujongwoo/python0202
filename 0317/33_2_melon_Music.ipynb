# %%
# 멜론 뮤직 Top 100 크롤링
import requests
from bs4 import BeautifulSoup
targetSite = 'https://www.melon.com/chart/index.htm'

# %%
request = requests.get(targetSite)
print(request) # <Response [406]> => 헤더 정보 때문에 읽어오지 못함
# Out:
# <Response [406]>

# %%
# 헤더 정보 때문에 웹 사이트의 데이터를 읽어오지 못할 경우
# https://developers.whatismybrowser.com/useragents/explore/layout_engine_name/trident/
# Mozilla/5.0 (compatible, MSIE 11, Windows NT 6.3; Trident/7.0; rv:11.0) like Gecko
header = {'User-Agent': 'Mozilla/5.0 (compatible, MSIE 11, Windows NT 6.3; Trident/7.0; rv:11.0) like Gecko'}
request = requests.get(targetSite, headers = header)
# print(request)
html = request.text
# print(html)
soup = BeautifulSoup(html, 'html.parser')
# print(soup)
# Out:
# <!DOCTYPE html>
#
# <html lang="ko">
# <head>
# <meta content="text/html; charset=utf-8" http-equiv="Content-Type"/>
# <meta content="IE=edge,chrome=1" http-equiv="X-UA-Compatible"/>
# <title>멜론차트&gt;멜론 TOP 100&gt;실시간&gt;멜론</title>
# <meta content="음악서비스, 멜론차트, 멜론TOP100, 최신음악, 인기가요, 뮤직비디오, 앨범, 플레이어, 스트리밍, 다운로드, 아티스트플러스, 아티스트채널" name="keywords"/>
# <meta content="국내 최다 4,000만곡 보유, No.1 뮤직플랫폼 멜론! 실시간 차트부터 나를 아는 똑똑한 음악추천까지!" name="description"/>
# <meta content="f13fc46b807bef984aa341efeb1adec8de12264c" name="naver-site-verification"/>
# <meta content="357952407588971" property="fb:app_id"/>
# <meta content="Melon" property="og:title"/>
# <meta content="https://cdnimg.melon.co.kr/resource/image/web/common/logo_melon142x99.png" property="og:image"/>
# <meta content="음악이 필요한 순간, 멜론" property="og:description"/>
# <meta content="http://www.melon.com/chart/index.htm" property="og:url"/>
# <meta content="website" property="og:type"/>
# <meta content="width=device-width" name="viewport"/>
# ...

# %%
# 노래 제목 크롤링
titles = soup.findAll('div', {'class': 'rank01'})
print(len(titles))
for title in titles:
    print(title.text.strip())
# Out:
# 100
# 시작
# ON
# 아무노래
# 마음을 드려요
# 00:00 (Zero O’Clock)
# Black Swan
# WANNABE
# 그때 그 아인
# METEOR
# 작은 것들을 위한 시 (Boy With Luv) (Feat. Halsey)
# 친구
# 돌덩이
# Filter
# FIESTA
# 시차
# Moon
# 흔들리는 꽃들 속에서 네 샴푸향이 느껴진거야
# Inner Child
# Sweet Night
# Louder than bombs
# 욱 (UGH!)
# We are Bulletproof : the Eternal
# Blueming
# Interlude : Shadow
# 늦은 밤 너의 집 앞 골목길에서
# 반만
# Respect
# Psycho
# Outro : Ego
# 영웅 (英雄; Kick It)
# 어떻게 지내
# 다시 난, 여기
# HIP
# 너를 사랑하고 있어
# 문득
# 화분
# 둘만의 세상으로 가
# 어떻게 이별까지 사랑하겠어, 널 사랑하는 거지
# 오늘도 빛나는 너에게 (To You My Light) (Feat.이라온)
# 2002
# Square (2017)
# Love poem
# 어떤 날엔
# 안녕
# 아마두 (feat.우원재, 김효은, 넉살, Huckleberry P)
# 사랑이란 멜로는 없어
# 마음이 말하는 행복 (Happiness) (Feat.이라온)
# Elevator (127F)
# 조금 취했어 (Prod. 2soo)
# 꿈 (Boom)
# 모든 날, 모든 순간 (Every day, Every Moment)
# 시든 꽃에 물을 주듯
# 사랑의 인사
# Interlude: Neo Zone
# 빌었어
# bad guy
# 우리 왜 헤어져야 해
# 낮잠 (Pandora's Box)
# 다시 만날까 봐
# 우산 (Love Song)
# 찐이야
# Day Dream (白日夢)
# 메아리 (Love Me Now)
# 나의 오랜 연인에게
# Sit Down!
# Paris In The Rain
# ...

# %%
# 가수 이름 크롤링
artists = soup.findAll('span', {'class': 'checkEllipsis'})
print(len(artists))
for artist in artists:
    print(artist.text.strip().split('\n')[0])
# Out:
# 100
# 가호 (Gaho)
# 방탄소년단
# 지코 (ZICO)
# 아이유
# 방탄소년단
# 방탄소년단
# ITZY (있지)
# 김필
# 창모 (CHANGMO)
# 방탄소년단
# 방탄소년단
# 하현우 (국카스텐)
# 방탄소년단
# IZ*ONE (아이즈원)
# 방탄소년단
# 방탄소년단
# 장범준
# 방탄소년단
# V
# 방탄소년단
# 방탄소년단
# 방탄소년단
# 아이유
# 방탄소년단
# 노을
# 진민호
# 방탄소년단
# Red Velvet (레드벨벳)
# 방탄소년단
# NCT 127
# 오반
# 백예린
# 마마무 (Mamamoo)
# 백현 (BAEKHYUN)
# 노을
# 세정
# Crush
# AKMU (악동뮤지션)
# 마크툽 (MAKTUB)
# Anne-Marie
# 백예린
# 아이유
# 김재환
# 폴킴
# 염따, 딥플로우, 팔로알토 (Paloalto), The Quiett, 사이먼 도미닉
# 전상근
# 마크툽 (MAKTUB)
# NCT 127
# 임재현
# NCT 127
# 폴킴
# HYNN (박혜원)
# 씨야
# NCT 127
# 창모 (CHANGMO)
# Billie Eilish
# 신예영
# NCT 127
# V.O.S
# NCT 127
# 영탁
# NCT 127
# NCT 127
# 다비치
# NCT 127
# Lauv
# NCT 127
# Ruel
# 윤미래
# NCT 127
# Conan Gray
# 방탄소년단
# 황인욱
# Anne-Marie
# 먼데이 키즈 (Monday Kiz)
# 윤미래
# 백지영
# 임재현
# KCM
# 이예준
# NCT 127
# NCT 127
# 폴킴
# 송가인
# 백현 (BAEKHYUN)
# Shawn Mendes, Camila Cabello
# 장덕철
# 거미
# Arizona Zervas
# Sam Smith
# 찬열 (CHANYEOL), 펀치 (Punch)
# EXO
# 김나영, 양다일
# 창모 (CHANGMO), Hash Swan, ASH ISLAND, 김효은
# 잔나비
# 송하예
# 송하예
# V.O.S
# ...

# %%
melon = [] # 노래 제목과 가수를 하나의 리스트로 만들어 저장할 빈 리스트를 선언한다.
titles = titles = soup.findAll('div', {'class': 'rank01'})
artists = soup.findAll('span', {'class': 'checkEllipsis'})
for i in range(len(titles)):
    melon.append([titles[i].text.strip(), artists[i].text.strip().split('\n')[0]])

from datetime import datetime as dt
print(dt.now(), '현재')
for i in range(len(melon)):
    print('{0:3d}위. {1} - {2}'.format(i + 1, melon[i][0], melon[i][1]))
# Out:
# 2020-03-17 20:14:26.486330 현재
#   1위. 시작 - 가호 (Gaho)
#   2위. ON - 방탄소년단
#   3위. 아무노래 - 지코 (ZICO)
#   4위. 마음을 드려요 - 아이유
#   5위. 00:00 (Zero O’Clock) - 방탄소년단
#   6위. Black Swan - 방탄소년단
#   7위. WANNABE - ITZY (있지)
#   8위. 그때 그 아인 - 김필
#   9위. METEOR - 창모 (CHANGMO)
#  10위. 작은 것들을 위한 시 (Boy With Luv) (Feat. Halsey) - 방탄소년단
#  11위. 친구 - 방탄소년단
#  12위. 돌덩이 - 하현우 (국카스텐)
#  13위. Filter - 방탄소년단
#  14위. FIESTA - IZ*ONE (아이즈원)
#  15위. 시차 - 방탄소년단
#  16위. Moon - 방탄소년단
#  17위. 흔들리는 꽃들 속에서 네 샴푸향이 느껴진거야 - 장범준
#  18위. Inner Child - 방탄소년단
#  19위. Sweet Night - V
#  20위. Louder than bombs - 방탄소년단
#  21위. 욱 (UGH!) - 방탄소년단
#  22위. We are Bulletproof : the Eternal - 방탄소년단
#  23위. Blueming - 아이유
#  24위. Interlude : Shadow - 방탄소년단
#  25위. 늦은 밤 너의 집 앞 골목길에서 - 노을
#  26위. 반만 - 진민호
#  27위. Respect - 방탄소년단
#  28위. Psycho - Red Velvet (레드벨벳)
#  29위. Outro : Ego - 방탄소년단
#  30위. 영웅 (英雄; Kick It) - NCT 127
#  31위. 어떻게 지내 - 오반
#  32위. 다시 난, 여기 - 백예린
#  33위. HIP - 마마무 (Mamamoo)
#  34위. 너를 사랑하고 있어 - 백현 (BAEKHYUN)
# ...

# %%
from datetime import datetime as dt

file = open('melonTop100.txt', 'w', -1, 'UTF-8')
file.write(str(dt.now()) + '\n')
for i in range(len(melon)):
    data = '{0:3d}위. {1} - {2}'.format(i + 1, melon[i][0], melon[i][1])
    # print(data)
    file.write(data + '\n')
file.close()
print('melonTop100.txt 파일에 쓰기 완료')
# Out:
# melonTop100.txt 파일에 쓰기 완료

# %%
file = open('melonTop100.txt', 'r', -1, 'UTF-8')
lines = file.readlines()
print('메론뮤직 TOP 100')
for line in lines:
    print(line, end = '')
print()
file.close()
# Out:
# 메론뮤직 TOP 100
# 2020-03-17 20:15:48.572200
#   1위. 시작 - 가호 (Gaho)
#   2위. ON - 방탄소년단
#   3위. 아무노래 - 지코 (ZICO)
#   4위. 마음을 드려요 - 아이유
#   5위. 00:00 (Zero O’Clock) - 방탄소년단
#   6위. Black Swan - 방탄소년단
#   7위. WANNABE - ITZY (있지)
#   8위. 그때 그 아인 - 김필
#   9위. METEOR - 창모 (CHANGMO)
#  10위. 작은 것들을 위한 시 (Boy With Luv) (Feat. Halsey) - 방탄소년단
#  11위. 친구 - 방탄소년단
#  12위. 돌덩이 - 하현우 (국카스텐)
#  13위. Filter - 방탄소년단
#  14위. FIESTA - IZ*ONE (아이즈원)
#  15위. 시차 - 방탄소년단
#  16위. Moon - 방탄소년단
#  17위. 흔들리는 꽃들 속에서 네 샴푸향이 느껴진거야 - 장범준
#  18위. Inner Child - 방탄소년단
#  19위. Sweet Night - V
#  20위. Louder than bombs - 방탄소년단
#  21위. 욱 (UGH!) - 방탄소년단
#  22위. We are Bulletproof : the Eternal - 방탄소년단
#  23위. Blueming - 아이유
#  24위. Interlude : Shadow - 방탄소년단
#  25위. 늦은 밤 너의 집 앞 골목길에서 - 노을
#  26위. 반만 - 진민호
#  27위. Respect - 방탄소년단
#  28위. Psycho - Red Velvet (레드벨벳)
#  29위. Outro : Ego - 방탄소년단
#  30위. 영웅 (英雄; Kick It) - NCT 127
#  31위. 어떻게 지내 - 오반
#  32위. 다시 난, 여기 - 백예린
#  33위. HIP - 마마무 (Mamamoo)
# ...
