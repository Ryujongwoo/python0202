# %%
# import할 모듈이 특정 폴더에 있는 경우 sys 라이브러를 import하고 sys.path에 import할 모듈이 위치한
# 경로를 append() 함수로 추가하면 된다.
import sys
# 소스 파일과 라이브러리가 같은 드라이브에 있으면 드라이브 이름을 생략할 수 있다.
sys.path.append('d:/myLib')

# %%
import selectionSortModuleMyLib as ssm

data = [8, 3, 4, 9, 1, 100]
data = ssm.selectionSortAsc(data)
print('오름차순 정렬 결과 : {}'.format(data))
data = ssm.selectionSortDesc(data)
print('내림차순 정렬 결과 : {}'.format(data))
# Out:
# 오름차순 정렬 결과 : [1, 3, 4, 8, 9, 100]
# 내림차순 정렬 결과 : [100, 9, 8, 4, 3, 1]
