# %%
# 특정 모듈의 특정 함수만 import 하려는 경우 또는 import한 함수를 마치 현재 프로그램에서 선언한
# 함수처럼 사용하려면 아래와 같이 하면 된다.

# from 모듈이름 import 함수이름
# from selectionSortModule import selectionSortAsc
# from selectionSortModule import selectionSortDesc

# 위의 2문장은 같은 모듈에 있는 함수를 import 시키고 있기 때문에 아래와 같이 줄여서 사용해도 된다.
# from selectionSortModule import selectionSortAsc, selectionSortDesc

# 아래와 같이 import 시키면 특정 모듈의 모든 함수를 import 시킬 수 있다.
from selectionSortModule import *

data = [8, 3, 4, 9, 1, 100]
data = selectionSortAsc(data)
print('오름차순 정렬 결과 : {}'.format(data))
data = selectionSortDesc(data)
print('내림차순 정렬 결과 : {}'.format(data))
# Out:
# 오름차순 정렬 결과 : [1, 3, 4, 8, 9, 100]
# 내림차순 정렬 결과 : [100, 9, 8, 4, 3, 1]
